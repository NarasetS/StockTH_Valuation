# %%
import pandas as pd
import yfinance as yf
import matplotlib
import numpy as np

# %%
date_start = "2018-01-01"
date_end = "2023-12-31"
market = yf.Ticker("^GSPC").history(start=date_start, end=date_end, interval="1d")
stock = yf.Ticker("ULTA").history(start=date_start, end=date_end, interval="1d")

# %%
data = pd.DataFrame()
data['market'] = market['Close']
data['stock'] = stock['Close']
data.reset_index(inplace=True)
data = data.drop(columns=['Date'])
data
# Out:
#            market       stock
# 0     2695.810059   59.770950
# 1     2713.060059   59.853737
# 2     2723.989990   59.789333
# 3     2743.149902   59.872131
# 4     2747.709961   60.230865
# ...           ...         ...
# 1504  4754.629883  127.362679
# 1505  4774.750000  126.769882
# 1506  4781.580078  126.345039
# 1507  4783.350098  126.048637
# 1508  4769.830078  125.673195
#
# [1509 rows x 2 columns]

# %%
def normalize(df):
  x = df.copy()
  for i in x.columns[0:]:
    x[i] = x[i]/x[i][0]
  return x

data = normalize(data)
data.plot()
# Out:
# <Axes: >

# %%
def daily_return(df):
    df_daily_return = df.copy()
    for i in df.columns[0:]:
        for j in range(1, len(df)):
            df_daily_return[i][j] = ((df[i][j]- df[i][j-1])/df[i][j-1]) * 100
        df_daily_return[i][0] = 0
    return df_daily_return

data_daily_return = daily_return(data)
data_daily_return
# Out:
# C:\Users\595078\AppData\Local\Temp\ipykernel_3724\2284912146.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_daily_return[i][j] = ((df[i][j]- df[i][j-1])/df[i][j-1]) * 100
# C:\Users\595078\AppData\Local\Temp\ipykernel_3724\2284912146.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_daily_return[i][0] = 0
#         market     stock
# 0     0.000000  0.000000
# 1     0.639882  0.138506
# 2     0.402864 -0.107602
# 3     0.703377  0.138483
# 4     0.166234  0.599167
# ...        ...       ...
# 1504  0.166006  1.768374
# 1505  0.423169 -0.465440
# 1506  0.143046 -0.335129
# 1507  0.037017 -0.234597
# 1508 -0.282648 -0.297855
#
# [1509 rows x 2 columns]

# %%
beta, alpha = np.polyfit(data_daily_return['market'], data_daily_return['stock'], 1)

# %%
data_daily_return['market'].mean()
rm = data_daily_return['market'].mean() * len(data_daily_return)
rf = 0 
ER_AAPL = rf + (beta * (rm-rf)) 
ER_AAPL
# Out:
# np.float64(57.76331728334431)
